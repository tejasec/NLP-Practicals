# %% [markdown]
# # Practical 2: Tokenization and Normalization

# %% [markdown]
# Import Libraries

# %%
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize

import nltk
import string
import re

nltk.download("punkt")
nltk.download("punkt_tab")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Nitish\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Nitish\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %% [markdown]
# Input Text

# %%
text = """
Natural Language Processing is an exciting field of Artificial Intelligence.
It allows computers to understand, process, and generate human language.
"""

# %% [markdown]
# Sentence Tokenization

# %%
sentences = sent_tokenize(text)

print("Sentence Tokenization")
print("-"*50)

for sentence in sentences:
    print(sentence)
# Out:
# Sentence Tokenization
# --------------------------------------------------
#
# Natural Language Processing is an exciting field of Artificial Intelligence.
# It allows computers to understand, process, and generate human language.

# %% [markdown]
# Word Tokenization

# %%
words = word_tokenize(text)

print("Word Tokenization")
print("-"*50)

print(words)
# Out:
# Word Tokenization
# --------------------------------------------------
# ['Natural', 'Language', 'Processing', 'is', 'an', 'exciting', 'field', 'of', 'Artificial', 'Intelligence', '.', 'It', 'allows', 'computers', 'to', 'understand', ',', 'process', ',', 'and', 'generate', 'human', 'language', '.']

# %% [markdown]
# Character Tokenization

# %%
characters = list(text)

print("Character Tokenization")
print("-"*50)

print(characters)
# Out:
# Character Tokenization
# --------------------------------------------------
# ['\n', 'N', 'a', 't', 'u', 'r', 'a', 'l', ' ', 'L', 'a', 'n', 'g', 'u', 'a', 'g', 'e', ' ', 'P', 'r', 'o', 'c', 'e', 's', 's', 'i', 'n', 'g', ' ', 'i', 's', ' ', 'a', 'n', ' ', 'e', 'x', 'c', 'i', 't', 'i', 'n', 'g', ' ', 'f', 'i', 'e', 'l', 'd', ' ', 'o', 'f', ' ', 'A', 'r', 't', 'i', 'f', 'i', 'c', 'i', 'a', 'l', ' ', 'I', 'n', 't', 'e', 'l', 'l', 'i', 'g', 'e', 'n', 'c', 'e', '.', '\n', 'I', 't', ' ', 'a', 'l', 'l', 'o', 'w', 's', ' ', 'c', 'o', 'm', 'p', 'u', 't', 'e', 'r', 's', ' ', 't', 'o', ' ', 'u', 'n', 'd', 'e', 'r', 's', 't', 'a', 'n', 'd', ',', ' ', 'p', 'r', 'o', 'c', 'e', 's', 's', ',', ' ', 'a', 'n', 'd', ' ', 'g', 'e', 'n', 'e', 'r', 'a', 't', 'e', ' ', 'h', 'u', 'm', 'a', 'n', ' ', 'l', 'a', 'n', 'g', 'u', 'a', 'g', 'e', '.', '\n']

# %% [markdown]
# Lowercase Normalization

# %%
lower_text = text.lower()

print("Lowercase")
print("-"*50)

print(lower_text)
# Out:
# Lowercase
# --------------------------------------------------
#
# natural language processing is an exciting field of artificial intelligence.
# it allows computers to understand, process, and generate human language.

# %% [markdown]
# Remove Punctuation

# %%
text_without_punctuation = lower_text.translate(
    str.maketrans("", "", string.punctuation)
)

print("Without Punctuation")
print("-"*50)

print(text_without_punctuation)
# Out:
# Without Punctuation
# --------------------------------------------------
#
# natural language processing is an exciting field of artificial intelligence
# it allows computers to understand process and generate human language

# %% [markdown]
# Remove Numbers

# %%
text_without_numbers = re.sub(r"\d+", "", text_without_punctuation)

print("Without Numbers")
print("-"*50)

print(text_without_numbers)
# Out:
# Without Numbers
# --------------------------------------------------
#
# natural language processing is an exciting field of artificial intelligence
# it allows computers to understand process and generate human language

# %% [markdown]
# Remove Extra Spaces

# %%
normalized_text = re.sub(r"\s+", " ", text_without_numbers).strip()

print("Normalized Text")
print("-"*50)

print(normalized_text)
# Out:
# Normalized Text
# --------------------------------------------------
# natural language processing is an exciting field of artificial intelligence it allows computers to understand process and generate human language

# %% [markdown]
# Final Tokenization

# %%
final_tokens = word_tokenize(normalized_text)

print("Final Tokens")
print("-"*50)

print(final_tokens)
# Out:
# Final Tokens
# --------------------------------------------------
# ['natural', 'language', 'processing', 'is', 'an', 'exciting', 'field', 'of', 'artificial', 'intelligence', 'it', 'allows', 'computers', 'to', 'understand', 'process', 'and', 'generate', 'human', 'language']
