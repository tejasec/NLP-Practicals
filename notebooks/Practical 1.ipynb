# %%
print("hello")
# Out:
# hello

# %% [markdown]
# # Practical 1: Text Preprocessing Pipeline Implementation

# %% [markdown]
# Import Required Libraries

# %%
# Tokenization
from nltk.tokenize import sent_tokenize, word_tokenize

# Stopwords
from nltk.corpus import stopwords

# Stemming
from nltk.stem import PorterStemmer

# Lemmatization
from nltk.stem import WordNetLemmatizer

# Regular Expressions
import re

# String Operations
import string

# NLTK
import nltk

# %% [markdown]
# Download Required NLTK Resources

# %%
nltk.download("punkt")
nltk.download("punkt_tab")
nltk.download("stopwords")
nltk.download("wordnet")
nltk.download("omw-1.4")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Nitish\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Nitish\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Nitish\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Nitish\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Nitish\AppData\Roaming\nltk_data...
# True

# %% [markdown]
# Create the Corpus

# %%
text = """
Machine Learning is one of the most important fields of Artificial Intelligence.
It enables computers to learn from data without being explicitly programmed.
Today, Machine Learning is used in healthcare, banking, education, e-commerce,
cybersecurity, self-driving cars, and recommendation systems.

Students study Machine Learning because it helps solve real-world problems.
However, before applying any machine learning algorithm,
the textual data must be cleaned and preprocessed.
Text preprocessing improves the quality of data by removing unnecessary
symbols, stopwords, punctuation, numbers, and extra spaces.
"""

# %% [markdown]
# Display Original Text

# %%
print("Original Corpus")
print(text)
# Out:
# Original Corpus
#
# Machine Learning is one of the most important fields of Artificial Intelligence.
# It enables computers to learn from data without being explicitly programmed.
# Today, Machine Learning is used in healthcare, banking, education, e-commerce,
# cybersecurity, self-driving cars, and recommendation systems.
#
# Students study Machine Learning because it helps solve real-world problems.
# However, before applying any machine learning algorithm,
# the textual data must be cleaned and preprocessed.
# Text preprocessing improves the quality of data by removing unnecessary
# symbols, stopwords, punctuation, numbers, and extra spaces.

# %% [markdown]
# Sentence Tokenization

# %%
sentences = sent_tokenize(text)

print("Sentence Tokenization")
print("-"*50)

for i, sentence in enumerate(sentences, start=1):
    print(f"Sentence {i}: {sentence}")
# Out:
# Sentence Tokenization
# --------------------------------------------------
# Sentence 1:
# Machine Learning is one of the most important fields of Artificial Intelligence.
# Sentence 2: It enables computers to learn from data without being explicitly programmed.
# Sentence 3: Today, Machine Learning is used in healthcare, banking, education, e-commerce,
# cybersecurity, self-driving cars, and recommendation systems.
# Sentence 4: Students study Machine Learning because it helps solve real-world problems.
# Sentence 5: However, before applying any machine learning algorithm,
# the textual data must be cleaned and preprocessed.
# Sentence 6: Text preprocessing improves the quality of data by removing unnecessary
# symbols, stopwords, punctuation, numbers, and extra spaces.

# %% [markdown]
# Word Tokenization

# %%
words = word_tokenize(text)

print("Word Tokenization")
print("-"*50)

print(words)
# Out:
# Word Tokenization
# --------------------------------------------------
# ['Machine', 'Learning', 'is', 'one', 'of', 'the', 'most', 'important', 'fields', 'of', 'Artificial', 'Intelligence', '.', 'It', 'enables', 'computers', 'to', 'learn', 'from', 'data', 'without', 'being', 'explicitly', 'programmed', '.', 'Today', ',', 'Machine', 'Learning', 'is', 'used', 'in', 'healthcare', ',', 'banking', ',', 'education', ',', 'e-commerce', ',', 'cybersecurity', ',', 'self-driving', 'cars', ',', 'and', 'recommendation', 'systems', '.', 'Students', 'study', 'Machine', 'Learning', 'because', 'it', 'helps', 'solve', 'real-world', 'problems', '.', 'However', ',', 'before', 'applying', 'any', 'machine', 'learning', 'algorithm', ',', 'the', 'textual', 'data', 'must', 'be', 'cleaned', 'and', 'preprocessed', '.', 'Text', 'preprocessing', 'improves', 'the', 'quality', 'of', 'data', 'by', 'removing', 'unnecessary', 'symbols', ',', 'stopwords', ',', 'punctuation', ',', 'numbers', ',', 'and', 'extra', 'spaces', '.']

# %% [markdown]
# Convert into Lowecase

# %%
lower_words = [word.lower() for word in words]

print("Lowercase Words")
print("-"*50)

print(lower_words)
# Out:
# Lowercase Words
# --------------------------------------------------
# ['machine', 'learning', 'is', 'one', 'of', 'the', 'most', 'important', 'fields', 'of', 'artificial', 'intelligence', '.', 'it', 'enables', 'computers', 'to', 'learn', 'from', 'data', 'without', 'being', 'explicitly', 'programmed', '.', 'today', ',', 'machine', 'learning', 'is', 'used', 'in', 'healthcare', ',', 'banking', ',', 'education', ',', 'e-commerce', ',', 'cybersecurity', ',', 'self-driving', 'cars', ',', 'and', 'recommendation', 'systems', '.', 'students', 'study', 'machine', 'learning', 'because', 'it', 'helps', 'solve', 'real-world', 'problems', '.', 'however', ',', 'before', 'applying', 'any', 'machine', 'learning', 'algorithm', ',', 'the', 'textual', 'data', 'must', 'be', 'cleaned', 'and', 'preprocessed', '.', 'text', 'preprocessing', 'improves', 'the', 'quality', 'of', 'data', 'by', 'removing', 'unnecessary', 'symbols', ',', 'stopwords', ',', 'punctuation', ',', 'numbers', ',', 'and', 'extra', 'spaces', '.']

# %% [markdown]
# Remove Punctuation

# %%
words_no_punctuation = [
    word for word in lower_words
    if word not in string.punctuation
]

print("After Removing Punctuation")
print("-"*50)

print(words_no_punctuation)
# Out:
# After Removing Punctuation
# --------------------------------------------------
# ['machine', 'learning', 'is', 'one', 'of', 'the', 'most', 'important', 'fields', 'of', 'artificial', 'intelligence', 'it', 'enables', 'computers', 'to', 'learn', 'from', 'data', 'without', 'being', 'explicitly', 'programmed', 'today', 'machine', 'learning', 'is', 'used', 'in', 'healthcare', 'banking', 'education', 'e-commerce', 'cybersecurity', 'self-driving', 'cars', 'and', 'recommendation', 'systems', 'students', 'study', 'machine', 'learning', 'because', 'it', 'helps', 'solve', 'real-world', 'problems', 'however', 'before', 'applying', 'any', 'machine', 'learning', 'algorithm', 'the', 'textual', 'data', 'must', 'be', 'cleaned', 'and', 'preprocessed', 'text', 'preprocessing', 'improves', 'the', 'quality', 'of', 'data', 'by', 'removing', 'unnecessary', 'symbols', 'stopwords', 'punctuation', 'numbers', 'and', 'extra', 'spaces']

# %% [markdown]
# Remove Numbers

# %%
words_no_numbers = [
    word for word in words_no_punctuation
    if word.isalpha()
]

print("After Removing Numbers")
print("-"*50)

print(words_no_numbers)
# Out:
# After Removing Numbers
# --------------------------------------------------
# ['machine', 'learning', 'is', 'one', 'of', 'the', 'most', 'important', 'fields', 'of', 'artificial', 'intelligence', 'it', 'enables', 'computers', 'to', 'learn', 'from', 'data', 'without', 'being', 'explicitly', 'programmed', 'today', 'machine', 'learning', 'is', 'used', 'in', 'healthcare', 'banking', 'education', 'cybersecurity', 'cars', 'and', 'recommendation', 'systems', 'students', 'study', 'machine', 'learning', 'because', 'it', 'helps', 'solve', 'problems', 'however', 'before', 'applying', 'any', 'machine', 'learning', 'algorithm', 'the', 'textual', 'data', 'must', 'be', 'cleaned', 'and', 'preprocessed', 'text', 'preprocessing', 'improves', 'the', 'quality', 'of', 'data', 'by', 'removing', 'unnecessary', 'symbols', 'stopwords', 'punctuation', 'numbers', 'and', 'extra', 'spaces']

# %% [markdown]
# Remove Stopwords

# %%
stop_words = set(stopwords.words("english"))

filtered_words = [
    word for word in words_no_numbers
    if word not in stop_words
]

print("After Stopword Removal")
print("-"*50)

print(filtered_words)
# Out:
# After Stopword Removal
# --------------------------------------------------
# ['machine', 'learning', 'one', 'important', 'fields', 'artificial', 'intelligence', 'enables', 'computers', 'learn', 'data', 'without', 'explicitly', 'programmed', 'today', 'machine', 'learning', 'used', 'healthcare', 'banking', 'education', 'cybersecurity', 'cars', 'recommendation', 'systems', 'students', 'study', 'machine', 'learning', 'helps', 'solve', 'problems', 'however', 'applying', 'machine', 'learning', 'algorithm', 'textual', 'data', 'must', 'cleaned', 'preprocessed', 'text', 'preprocessing', 'improves', 'quality', 'data', 'removing', 'unnecessary', 'symbols', 'stopwords', 'punctuation', 'numbers', 'extra', 'spaces']

# %% [markdown]
# Stemming

# %%
stemmer = PorterStemmer()

stemmed_words = [
    stemmer.stem(word)
    for word in filtered_words
]

print("After Stemming")
print("-"*50)

print(stemmed_words)
# Out:
# After Stemming
# --------------------------------------------------
# ['machin', 'learn', 'one', 'import', 'field', 'artifici', 'intellig', 'enabl', 'comput', 'learn', 'data', 'without', 'explicitli', 'program', 'today', 'machin', 'learn', 'use', 'healthcar', 'bank', 'educ', 'cybersecur', 'car', 'recommend', 'system', 'student', 'studi', 'machin', 'learn', 'help', 'solv', 'problem', 'howev', 'appli', 'machin', 'learn', 'algorithm', 'textual', 'data', 'must', 'clean', 'preprocess', 'text', 'preprocess', 'improv', 'qualiti', 'data', 'remov', 'unnecessari', 'symbol', 'stopword', 'punctuat', 'number', 'extra', 'space']

# %% [markdown]
# Lemmatization

# %%
lemmatizer = WordNetLemmatizer()

lemmatized_words = [
    lemmatizer.lemmatize(word)
    for word in filtered_words
]

print("After Lemmatization")
print("-"*50)

print(lemmatized_words)
# Out:
# After Lemmatization
# --------------------------------------------------
# ['machine', 'learning', 'one', 'important', 'field', 'artificial', 'intelligence', 'enables', 'computer', 'learn', 'data', 'without', 'explicitly', 'programmed', 'today', 'machine', 'learning', 'used', 'healthcare', 'banking', 'education', 'cybersecurity', 'car', 'recommendation', 'system', 'student', 'study', 'machine', 'learning', 'help', 'solve', 'problem', 'however', 'applying', 'machine', 'learning', 'algorithm', 'textual', 'data', 'must', 'cleaned', 'preprocessed', 'text', 'preprocessing', 'improves', 'quality', 'data', 'removing', 'unnecessary', 'symbol', 'stopwords', 'punctuation', 'number', 'extra', 'space']

# %% [markdown]
# Create Final Corpus

# %%
final_corpus = " ".join(lemmatized_words)

print("Final Clean Corpus")
print("-"*50)

print(final_corpus)
# Out:
# Final Clean Corpus
# --------------------------------------------------
# machine learning one important field artificial intelligence enables computer learn data without explicitly programmed today machine learning used healthcare banking education cybersecurity car recommendation system student study machine learning help solve problem however applying machine learning algorithm textual data must cleaned preprocessed text preprocessing improves quality data removing unnecessary symbol stopwords punctuation number extra space

# %% [markdown]
# Save Final Corpus

# %%
with open("final_corpus.txt", "w", encoding="utf-8") as file:
    file.write(final_corpus)

print("Corpus Saved Successfully!")
# Out:
# Corpus Saved Successfully!
